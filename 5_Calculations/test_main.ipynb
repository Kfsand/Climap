# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import random
from scipy import stats
from six.moves import urllib
import json
import pandas as pd
import math

from counter import var_counter
from plot import histoplot
import sys

from Classes import DataO
from Classes import MapO

# %%
datapath="../3_Raw_Data/60_Monthly_MeanTemp_2022-2100_UK"
resultpath="../6_Results/270722_full_map_tests/"

# %%
#### RUNNING ANALYSIS ####

# %%
#** Generating the threshold table ***

thresh_df=pd.DataFrame(
    columns=["Maxtemp",
            "Mintemp",
            "Avgtemp",
            "Rain",
            "Wind",
            "Snow"],
    index= ["Thermoelectric",
            "Hydroelectric",
            "Wind",
            "Solar PV",
            "Transformers",
            "Poles",
            "Overhead Lines",
            "Demand"]
)

thresh_df['Maxtemp']=[22,35,35,35,35,35,35,35]
thresh_df['Mintemp']=[3,0,0,0,0,0,0,0]
thresh_df['Avgtemp']=[20,25,25,25,25,25,25,25]
thresh_df['Rain']=[5,50,50,50,50,50,50,50]
thresh_df['Wind']=[20,30,30,30,30,30,30,30]
thresh_df['Snow']=[1,50,50,50,50,50,50,50]

'TESTING'
print(thresh_df)
# Out:
#                 Maxtemp  Mintemp  Avgtemp  Rain  Wind  Snow
# Thermoelectric       22        3       20     5    20     1
# Hydroelectric        35        0       25    50    30    50
# Wind                 35        0       25    50    30    50
# Solar PV             35        0       25    50    30    50
# Transformers         35        0       25    50    30    50
# Poles                35        0       25    50    30    50
# Overhead Lines       35        0       25    50    30    50
# Demand               35        0       25    50    30    50

# %%
### LOAD ALL WEATHER VARIABLE DATA ###

spatial_res=5
time_res='monthly'

Maxtemp=DataO.DataObject(title="5_Monthly_Maxtemp_2021_2040_UK",
                        varname="Maxtemp",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Maxtemp_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Maxtemp_2021_2040_UK",
                        respath='../6_Results/data/')


Avgtemp=DataO.DataObject(title="5_Monthly_Avgtemp_2021_2040_UK",
                        varname="Avgtemp",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Avgtemp_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Avgtemp_2021_2040_UK",
                        respath='../6_Results/data/')

Mintemp=DataO.DataObject(title="5_Monthly_Mintemp_2021_2040_UK",
                        varname="Mintemp",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Mintemp_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Mintemp_2021_2040_UK",
                        respath='../6_Results/data/')

Rain=DataO.DataObject(title="5_Monthly_Rain_2021_2040_UK",
                        varname="Rain",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Rain_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Rain_2021_2040_UK",
                        respath='../6_Results/data/')

Snow=DataO.DataObject(title="5_Monthly_Snow_2021_2040_UK",
                        varname="Snow",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Snow_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Snow_2021_2040_UK",
                        respath='../6_Results/data/')

WeatherVariables=[Maxtemp,Mintemp,Avgtemp,Rain,Snow]

'TESTING'
for object in WeatherVariables:
    assert object.untreated_array.shape == (12,239,244,153), 'Loaded data array does not have expected shape'

# %%
### RUNNING STAT TESTS ###

Maxtemp.run_stats(KStest=False,stats=True,tp_90=True)
Mintemp.run_stats(KStest=False,stats=True,tp_90=True)
Avgtemp.run_stats(KStest=False,stats=True,tp_90=True)
Rain.run_stats(KStest=False,stats=True,tp_90=True)
Snow.run_stats(KStest=False,stats=True,tp_90=True)

# %%
'TODO: update with correct row as component'

### SETTING THRESHOLDS FOR EACH VARIABLE ###
for variable in WeatherVariables:
    threshold=thresh_df[variable.varname]["Thermoelectric"]
    variable.set_threshold(threshold)


'Testing'
for variable in WeatherVariables:
    assert variable.threshold==thresh_df[variable.varname]["Thermoelectric"]

# %%
### COUNTING EXCESS DAYS ###

[counter, fcounter]=Maxtemp.counter()
Mintemp.counter()
Avgtemp.counter()
Rain.counter()
Snow.counter()
# Out:
# [array([[[16, 18, 17, ..., 10, 10,  8],
#          [26, 24, 26, ..., 11, 12, 10],
#          [38, 33, 33, ..., 13, 13, 14],
#          ...,
#          [ 0,  0,  0, ..., 11,  5,  4],
#          [ 0,  0,  0, ...,  5,  4,  2],
#          [ 0,  0,  0, ...,  1,  2,  1]]], dtype=int32),
#  array([16, 26, 38, ...,  4,  2,  1], dtype=int32)]

# %%
## Tests on counter array
print(np.amax(counter))
# Out:
# 84

# %%
### CREATING MAP ###

Map_5_Monthly_2021_2040=MapO.MapObject("Maxtemp - Excess days",Maxtemp,respath=resultpath)
Map_5_Monthly_2021_2040.build_props()
Map_5_Monthly_2021_2040.geojson_write('2707_244rows_test')

# %%
spatial_res=5
time_res='monthly'

Maxtemp_244=DataO.DataObject(title="5_Monthly_Maxtemp_2021_2040_UK",
                        varname="Maxtemp",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Maxtemp_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Maxtemp_2021_2040_UK",
                        respath='../6_Results/data/',data_rows=244)

last_read_table_244=Maxtemp_244.table

Maxtemp_243=DataO.DataObject(title="5_Monthly_Maxtemp_2021_2040_UK",
                        varname="Maxtemp",sres=spatial_res,tres=time_res,
                        fdname="5_Monthly_Maxtemp_2021_2040_UK",
                        fdpath="../3_Raw_Data/5_Monthly_Maxtemp_2021_2040_UK",
                        respath='../6_Results/data/',data_rows=243)

last_read_table_243=Maxtemp_243.table

# %%
Maxtemp_243.run_stats(KStest=False,stats=True,tp_90=True)
Maxtemp_243.set_threshold(22)
[counter_243, fcounter_243, slice_243, sum_243]=Maxtemp_243.counter()

Map_5_Monthly_2021_2040=MapO.MapObject("Maxtemp - Excess days",Maxtemp_243,respath=resultpath)
Map_5_Monthly_2021_2040.build_props()
Map_5_Monthly_2021_2040.geojson_write('2707_243rows_test')

# %%
#untreated_array
uarray_244=Maxtemp_244.untreated_array
uarray_243=Maxtemp_243.untreated_array


newuarray_243=uarray_243[0,1,:,:]
newuarray_244=uarray_244[0,1,:243,:]
if not np.array_equal(newuarray_244,newuarray_243):
    print("help in table (" + str(i) + ","+ str(j) + ")")
# Out:
# help in table (11,238)

# %%
for i in range(12):
    for j in range(239):
        newuarray_243=uarray_243[i,j,:,:]
        newuarray_244=uarray_244[i,j,:243,:]
        if not np.array_equal(newuarray_244,newuarray_243):
            print("help in table (" + str(i) + ","+ str(j) + ")")
# Out:
# help in table (0,1)
# help in table (0,2)
# help in table (0,3)
# help in table (0,4)
# help in table (0,5)
# help in table (0,6)
# help in table (0,7)
# help in table (0,8)
# help in table (0,9)
# help in table (0,10)
# help in table (0,11)
# help in table (0,12)
# help in table (0,13)
# help in table (0,14)
# help in table (0,15)
# help in table (0,16)
# help in table (0,17)
# help in table (0,18)
# help in table (0,19)
# help in table (0,20)
# help in table (0,21)
# help in table (0,22)
# help in table (0,23)
# help in table (0,24)
# help in table (0,25)
# help in table (0,26)
# help in table (0,27)
# help in table (0,28)
# help in table (0,29)
# help in table (0,30)
# help in table (0,31)
# help in table (0,32)
# help in table (0,33)
# help in table (0,34)
# help in table (0,35)
# help in table (0,36)
# help in table (0,37)
# help in table (0,38)
# help in table (0,39)
# help in table (0,40)
# help in table (0,41)
# help in table (0,42)
# help in table (0,43)
# help in table (0,44)
# help in table (0,45)
# help in table (0,46)
# help in table (0,47)
# help in table (0,48)
# help in table (0,49)
# help in table (0,50)
# help in table (0,51)
# help in table (0,52)
# help in table (0,53)
# help in table (0,54)
# help in table (0,55)
# help in table (0,56)
# help in table (0,57)
# help in table (0,58)
# help in table (0,59)
# help in table (0,60)
# help in table (0,61)
# help in table (0,62)
# help in table (0,63)
# help in table (0,64)
# help in table (0,65)
# help in table (0,66)
# help in table (0,67)
# help in table (0,68)
# help in table (0,69)
# help in table (0,70)
# help in table (0,71)
# help in table (0,72)
# help in table (0,73)
# help in table (0,74)
# help in table (0,75)
# help in table (0,76)
# help in table (0,77)
# help in table (0,78)
# help in table (0,79)
# help in table (0,80)
# help in table (0,81)
# help in table (0,82)
# help in table (0,83)
# help in table (0,84)
# help in table (0,85)
# help in table (0,86)
# help in table (0,87)
# help in table (0,88)
# help in table (0,89)
# help in table (0,90)
# help in table (0,91)
# help in table (0,92)
# help in table (0,93)
# help in table (0,94)
# help in table (0,95)
# help in table (0,96)
# help in table (0,97)
# help in table (0,98)
# help in table (0,99)
# help in table (0,100)
# help in table (0,101)
# help in table (0,102)
# help in table (0,103)
# help in table (0,104)
# help in table (0,105)
# help in table (0,106)
# help in table (0,107)
# help in table (0,108)
# help in table (0,109)
# help in table (0,110)
# help in table (0,111)
# help in table (0,112)
# help in table (0,113)
# help in table (0,114)
# help in table (0,115)
# help in table (0,116)
# help in table (0,117)
# help in table (0,118)
# help in table (0,119)
# help in table (0,120)
# help in table (0,121)
# help in table (0,122)
# help in table (0,123)
# help in table (0,124)
# help in table (0,125)
# help in table (0,126)
# help in table (0,127)
# help in table (0,128)
# help in table (0,129)
# help in table (0,130)
# help in table (0,131)
# help in table (0,132)
# help in table (0,133)
# help in table (0,134)
# help in table (0,135)
# help in table (0,136)
# help in table (0,137)
# help in table (0,138)
# help in table (0,139)
# help in table (0,140)
# help in table (0,141)
# help in table (0,142)
# help in table (0,143)
# help in table (0,144)
# help in table (0,145)
# help in table (0,146)
# help in table (0,147)
# help in table (0,148)
# help in table (0,149)
# help in table (0,150)
# help in table (0,151)
# help in table (0,152)
# help in table (0,153)
# help in table (0,154)
# help in table (0,155)
# help in table (0,156)
# help in table (0,157)
# help in table (0,158)
# help in table (0,159)
# help in table (0,160)
# help in table (0,161)
# help in table (0,162)
# help in table (0,163)
# help in table (0,164)
# help in table (0,165)
# help in table (0,166)
# help in table (0,167)
# help in table (0,168)
# help in table (0,169)
# help in table (0,170)
# help in table (0,171)
# help in table (0,172)
# help in table (0,173)
# help in table (0,174)
# help in table (0,175)
# help in table (0,176)
# help in table (0,177)
# help in table (0,178)
# help in table (0,179)
# help in table (0,180)
# help in table (0,181)
# help in table (0,182)
# help in table (0,183)
# help in table (0,184)
# help in table (0,185)
# help in table (0,186)
# help in table (0,187)
# help in table (0,188)
# help in table (0,189)
# help in table (0,190)
# help in table (0,191)
# help in table (0,192)
# help in table (0,193)
# help in table (0,194)
# help in table (0,195)
# help in table (0,196)
# help in table (0,197)
# help in table (0,198)
# help in table (0,199)
# help in table (0,200)
# help in table (0,201)
# help in table (0,202)
# help in table (0,203)
# help in table (0,204)
# help in table (0,205)
# help in table (0,206)
# help in table (0,207)
# help in table (0,208)
# help in table (0,209)
# help in table (0,210)
# help in table (0,211)
# help in table (0,212)
# help in table (0,213)
# help in table (0,214)
# help in table (0,215)
# help in table (0,216)
# help in table (0,217)
# help in table (0,218)
# help in table (0,219)
# help in table (0,220)
# help in table (0,221)
# help in table (0,222)
# help in table (0,223)
# help in table (0,224)
# help in table (0,225)
# help in table (0,226)
# help in table (0,227)
# help in table (0,228)
# help in table (0,229)
# help in table (0,230)
# help in table (0,231)
# help in table (0,232)
# help in table (0,233)
# help in table (0,234)
# help in table (0,235)
# help in table (0,236)
# help in table (0,237)
# help in table (0,238)
# help in table (1,1)
# help in table (1,2)
# help in table (1,3)
# help in table (1,4)
# help in table (1,5)
# help in table (1,6)
# help in table (1,7)
# help in table (1,8)
# help in table (1,9)
# help in table (1,10)
# help in table (1,11)
# help in table (1,12)
# help in table (1,13)
# help in table (1,14)
# help in table (1,15)
# help in table (1,16)
# help in table (1,17)
# help in table (1,18)
# help in table (1,19)
# help in table (1,20)
# help in table (1,21)
# help in table (1,22)
# help in table (1,23)
# help in table (1,24)
# help in table (1,25)
# help in table (1,26)
# help in table (1,27)
# help in table (1,28)
# help in table (1,29)
# help in table (1,30)
# help in table (1,31)
# help in table (1,32)
# help in table (1,33)
# help in table (1,34)
# help in table (1,35)
# help in table (1,36)
# help in table (1,37)
# help in table (1,38)
# help in table (1,39)
# help in table (1,40)
# help in table (1,41)
# help in table (1,42)
# help in table (1,43)
# help in table (1,44)
# help in table (1,45)
# help in table (1,46)
# help in table (1,47)
# help in table (1,48)
# help in table (1,49)
# help in table (1,50)
# help in table (1,51)
# help in table (1,52)
# help in table (1,53)
# help in table (1,54)
# help in table (1,55)
# help in table (1,56)
# help in table (1,57)
# help in table (1,58)
# help in table (1,59)
# help in table (1,60)
# help in table (1,61)
# help in table (1,62)
# help in table (1,63)
# help in table (1,64)
# help in table (1,65)
# help in table (1,66)
# help in table (1,67)
# help in table (1,68)
# help in table (1,69)
# help in table (1,70)
# help in table (1,71)
# help in table (1,72)
# help in table (1,73)
# help in table (1,74)
# help in table (1,75)
# help in table (1,76)
# help in table (1,77)
# help in table (1,78)
# help in table (1,79)
# help in table (1,80)
# help in table (1,81)
# help in table (1,82)
# help in table (1,83)
# help in table (1,84)
# help in table (1,85)
# help in table (1,86)
# help in table (1,87)
# help in table (1,88)
# help in table (1,89)
# help in table (1,90)
# help in table (1,91)
# help in table (1,92)
# help in table (1,93)
# help in table (1,94)
# help in table (1,95)
# help in table (1,96)
# help in table (1,97)
# help in table (1,98)
# help in table (1,99)
# help in table (1,100)
# help in table (1,101)
# help in table (1,102)
# help in table (1,103)
# help in table (1,104)
# help in table (1,105)
# help in table (1,106)
# help in table (1,107)
# help in table (1,108)
# help in table (1,109)
# help in table (1,110)
# help in table (1,111)
# help in table (1,112)
# help in table (1,113)
# help in table (1,114)
# help in table (1,115)
# help in table (1,116)
# help in table (1,117)
# help in table (1,118)
# help in table (1,119)
# help in table (1,120)
# help in table (1,121)
# help in table (1,122)
# help in table (1,123)
# help in table (1,124)
# help in table (1,125)
# help in table (1,126)
# help in table (1,127)
# help in table (1,128)
# help in table (1,129)
# help in table (1,130)
# help in table (1,131)
# help in table (1,132)
# help in table (1,133)
# help in table (1,134)
# help in table (1,135)
# help in table (1,136)
# help in table (1,137)
# help in table (1,138)
# help in table (1,139)
# help in table (1,140)
# help in table (1,141)
# help in table (1,142)
# help in table (1,143)
# help in table (1,144)
# help in table (1,145)
# help in table (1,146)
# help in table (1,147)
# help in table (1,148)
# help in table (1,149)
# help in table (1,150)
# help in table (1,151)
# help in table (1,152)
# help in table (1,153)
# help in table (1,154)
# help in table (1,155)
# help in table (1,156)
# help in table (1,157)
# help in table (1,158)
# help in table (1,159)
# help in table (1,160)
# help in table (1,161)
# help in table (1,162)
# help in table (1,163)
# help in table (1,164)
# help in table (1,165)
# help in table (1,166)
# help in table (1,167)
# help in table (1,168)
# help in table (1,169)
# help in table (1,170)
# help in table (1,171)
# help in table (1,172)
# help in table (1,173)
# help in table (1,174)
# help in table (1,175)
# help in table (1,176)
# help in table (1,177)
# help in table (1,178)
# help in table (1,179)
# help in table (1,180)
# help in table (1,181)
# help in table (1,182)
# help in table (1,183)
# help in table (1,184)
# help in table (1,185)
# help in table (1,186)
# help in table (1,187)
# help in table (1,188)
# help in table (1,189)
# help in table (1,190)
# help in table (1,191)
# help in table (1,192)
# help in table (1,193)
# help in table (1,194)
# help in table (1,195)
# help in table (1,196)
# help in table (1,197)
# help in table (1,198)
# help in table (1,199)
# help in table (1,200)
# help in table (1,201)
# help in table (1,202)
# help in table (1,203)
# help in table (1,204)
# help in table (1,205)
# help in table (1,206)
# help in table (1,207)
# help in table (1,208)
# help in table (1,209)
# help in table (1,210)
# help in table (1,211)
# help in table (1,212)
# help in table (1,213)
# help in table (1,214)
# help in table (1,215)
# help in table (1,216)
# help in table (1,217)
# help in table (1,218)
# help in table (1,219)
# help in table (1,220)
# help in table (1,221)
# help in table (1,222)
# help in table (1,223)
# help in table (1,224)
# help in table (1,225)
# help in table (1,226)
# help in table (1,227)
# help in table (1,228)
# help in table (1,229)
# help in table (1,230)
# help in table (1,231)
# help in table (1,232)
# help in table (1,233)
# help in table (1,234)
# help in table (1,235)
# help in table (1,236)
# help in table (1,237)
# help in table (1,238)
# help in table (2,1)
# help in table (2,2)
# help in table (2,3)
# help in table (2,4)
# help in table (2,5)
# help in table (2,6)
# help in table (2,7)
# help in table (2,8)
# help in table (2,9)
# help in table (2,10)
# help in table (2,11)
# help in table (2,12)
# help in table (2,13)
# help in table (2,14)
# help in table (2,15)
# help in table (2,16)
# help in table (2,17)
# help in table (2,18)
# help in table (2,19)
# help in table (2,20)
# help in table (2,21)
# help in table (2,22)
# help in table (2,23)
# help in table (2,24)
# help in table (2,25)
# help in table (2,26)
# help in table (2,27)
# help in table (2,28)
# help in table (2,29)
# help in table (2,30)
# help in table (2,31)
# help in table (2,32)
# help in table (2,33)
# help in table (2,34)
# help in table (2,35)
# help in table (2,36)
# help in table (2,37)
# help in table (2,38)
# help in table (2,39)
# help in table (2,40)
# help in table (2,41)
# help in table (2,42)
# help in table (2,43)
# help in table (2,44)
# help in table (2,45)
# help in table (2,46)
# help in table (2,47)
# help in table (2,48)
# help in table (2,49)
# help in table (2,50)
# help in table (2,51)
# help in table (2,52)
# help in table (2,53)
# help in table (2,54)
# help in table (2,55)
# help in table (2,56)
# help in table (2,57)
# help in table (2,58)
# help in table (2,59)
# help in table (2,60)
# help in table (2,61)
# help in table (2,62)
# help in table (2,63)
# help in table (2,64)
# help in table (2,65)
# help in table (2,66)
# help in table (2,67)
# help in table (2,68)
# help in table (2,69)
# help in table (2,70)
# help in table (2,71)
# help in table (2,72)
# help in table (2,73)
# help in table (2,74)
# help in table (2,75)
# help in table (2,76)
# help in table (2,77)
# help in table (2,78)
# help in table (2,79)
# help in table (2,80)
# help in table (2,81)
# help in table (2,82)
# help in table (2,83)
# help in table (2,84)
# help in table (2,85)
# help in table (2,86)
# help in table (2,87)
# help in table (2,88)
# help in table (2,89)
# help in table (2,90)
# help in table (2,91)
# help in table (2,92)
# help in table (2,93)
# help in table (2,94)
# help in table (2,95)
# help in table (2,96)
# help in table (2,97)
# help in table (2,98)
# help in table (2,99)
# help in table (2,100)
# help in table (2,101)
# help in table (2,102)
# help in table (2,103)
# help in table (2,104)
# help in table (2,105)
# help in table (2,106)
# help in table (2,107)
# help in table (2,108)
# help in table (2,109)
# help in table (2,110)
# help in table (2,111)
# help in table (2,112)
# help in table (2,113)
# help in table (2,114)
# help in table (2,115)
# help in table (2,116)
# help in table (2,117)
# help in table (2,118)
# help in table (2,119)
# help in table (2,120)
# help in table (2,121)
# help in table (2,122)
# help in table (2,123)
# help in table (2,124)
# help in table (2,125)
# help in table (2,126)
# help in table (2,127)
# help in table (2,128)
# help in table (2,129)
# help in table (2,130)
# help in table (2,131)
# help in table (2,132)
# help in table (2,133)
# help in table (2,134)
# help in table (2,135)
# help in table (2,136)
# help in table (2,137)
# help in table (2,138)
# help in table (2,139)
# help in table (2,140)
# help in table (2,141)
# help in table (2,142)
# help in table (2,143)
# help in table (2,144)
# help in table (2,145)
# help in table (2,146)
# help in table (2,147)
# help in table (2,148)
# help in table (2,149)
# help in table (2,150)
# help in table (2,151)
# help in table (2,152)
# help in table (2,153)
# help in table (2,154)
# help in table (2,155)
# help in table (2,156)
# help in table (2,157)
# help in table (2,158)
# help in table (2,159)
# help in table (2,160)
# help in table (2,161)
# help in table (2,162)
# help in table (2,163)
# help in table (2,164)
# help in table (2,165)
# help in table (2,166)
# help in table (2,167)
# help in table (2,168)
# help in table (2,169)
# help in table (2,170)
# help in table (2,171)
# help in table (2,172)
# help in table (2,173)
# help in table (2,174)
# help in table (2,175)
# help in table (2,176)
# help in table (2,177)
# help in table (2,178)
# help in table (2,179)
# help in table (2,180)
# help in table (2,181)
# help in table (2,182)
# help in table (2,183)
# help in table (2,184)
# help in table (2,185)
# help in table (2,186)
# help in table (2,187)
# help in table (2,188)
# help in table (2,189)
# help in table (2,190)
# help in table (2,191)
# help in table (2,192)
# help in table (2,193)
# help in table (2,194)
# help in table (2,195)
# help in table (2,196)
# help in table (2,197)
# help in table (2,198)
# help in table (2,199)
# help in table (2,200)
# help in table (2,201)
# help in table (2,202)
# help in table (2,203)
# help in table (2,204)
# help in table (2,205)
# help in table (2,206)
# help in table (2,207)
# help in table (2,208)
# help in table (2,209)
# help in table (2,210)
# help in table (2,211)
# help in table (2,212)
# help in table (2,213)
# help in table (2,214)
# help in table (2,215)
# help in table (2,216)
# help in table (2,217)
# help in table (2,218)
# help in table (2,219)
# help in table (2,220)
# help in table (2,221)
# help in table (2,222)
# help in table (2,223)
# help in table (2,224)
# help in table (2,225)
# help in table (2,226)
# help in table (2,227)
# help in table (2,228)
# help in table (2,229)
# help in table (2,230)
# help in table (2,231)
# help in table (2,232)
# help in table (2,233)
# help in table (2,234)
# help in table (2,235)
# help in table (2,236)
# help in table (2,237)
# help in table (2,238)
# help in table (3,1)
# help in table (3,2)
# help in table (3,3)
# help in table (3,4)
# help in table (3,5)
# help in table (3,6)
# help in table (3,7)
# help in table (3,8)
# help in table (3,9)
# help in table (3,10)
# help in table (3,11)
# help in table (3,12)
# help in table (3,13)
# help in table (3,14)
# help in table (3,15)
# help in table (3,16)
# help in table (3,17)
# help in table (3,18)
# help in table (3,19)
# help in table (3,20)
# help in table (3,21)
# help in table (3,22)
# help in table (3,23)
# help in table (3,24)
# help in table (3,25)
# help in table (3,26)
# help in table (3,27)
# help in table (3,28)
# help in table (3,29)
# help in table (3,30)
# help in table (3,31)
# help in table (3,32)
# help in table (3,33)
# help in table (3,34)
# help in table (3,35)
# help in table (3,36)
# help in table (3,37)
# help in table (3,38)
# help in table (3,39)
# help in table (3,40)
# help in table (3,41)
# help in table (3,42)
# help in table (3,43)
# help in table (3,44)
# help in table (3,45)
# help in table (3,46)
# help in table (3,47)
# help in table (3,48)
# help in table (3,49)
# help in table (3,50)
# help in table (3,51)
# help in table (3,52)
# help in table (3,53)
# help in table (3,54)
# help in table (3,55)
# help in table (3,56)
# help in table (3,57)
# help in table (3,58)
# help in table (3,59)
# help in table (3,60)
# help in table (3,61)
# help in table (3,62)
# help in table (3,63)
# help in table (3,64)
# help in table (3,65)
# help in table (3,66)
# help in table (3,67)
# help in table (3,68)
# help in table (3,69)
# help in table (3,70)
# help in table (3,71)
# help in table (3,72)
# help in table (3,73)
# help in table (3,74)
# help in table (3,75)
# help in table (3,76)
# help in table (3,77)
# help in table (3,78)
# help in table (3,79)
# help in table (3,80)
# help in table (3,81)
# help in table (3,82)
# help in table (3,83)
# help in table (3,84)
# help in table (3,85)
# help in table (3,86)
# help in table (3,87)
# help in table (3,88)
# help in table (3,89)
# help in table (3,90)
# help in table (3,91)
# help in table (3,92)
# help in table (3,93)
# help in table (3,94)
# help in table (3,95)
# help in table (3,96)
# help in table (3,97)
# help in table (3,98)
# help in table (3,99)
# help in table (3,100)
# help in table (3,101)
# help in table (3,102)
# help in table (3,103)
# help in table (3,104)
# help in table (3,105)
# help in table (3,106)
# help in table (3,107)
# help in table (3,108)
# help in table (3,109)
# help in table (3,110)
# help in table (3,111)
# help in table (3,112)
# help in table (3,113)
# help in table (3,114)
# help in table (3,115)
# help in table (3,116)
# help in table (3,117)
# help in table (3,118)
# help in table (3,119)
# help in table (3,120)
# help in table (3,121)
# help in table (3,122)
# help in table (3,123)
# help in table (3,124)
# help in table (3,125)
# help in table (3,126)
# help in table (3,127)
# help in table (3,128)
# help in table (3,129)
# help in table (3,130)
# help in table (3,131)
# help in table (3,132)
# help in table (3,133)
# help in table (3,134)
# help in table (3,135)
# help in table (3,136)
# help in table (3,137)
# help in table (3,138)
# help in table (3,139)
# help in table (3,140)
# help in table (3,141)
# help in table (3,142)
# help in table (3,143)
# help in table (3,144)
# help in table (3,145)
# help in table (3,146)
# help in table (3,147)
# help in table (3,148)
# help in table (3,149)
# help in table (3,150)
# help in table (3,151)
# help in table (3,152)
# help in table (3,153)
# help in table (3,154)
# help in table (3,155)
# help in table (3,156)
# help in table (3,157)
# help in table (3,158)
# help in table (3,159)
# help in table (3,160)
# help in table (3,161)
# help in table (3,162)
# help in table (3,163)
# help in table (3,164)
# help in table (3,165)
# help in table (3,166)
# help in table (3,167)
# help in table (3,168)
# help in table (3,169)
# help in table (3,170)
# help in table (3,171)
# help in table (3,172)
# help in table (3,173)
# help in table (3,174)
# help in table (3,175)
# help in table (3,176)
# help in table (3,177)
# help in table (3,178)
# help in table (3,179)
# help in table (3,180)
# help in table (3,181)
# help in table (3,182)
# help in table (3,183)
# help in table (3,184)
# help in table (3,185)
# help in table (3,186)
# help in table (3,187)
# help in table (3,188)
# help in table (3,189)
# help in table (3,190)
# help in table (3,191)
# help in table (3,192)
# help in table (3,193)
# help in table (3,194)
# help in table (3,195)
# help in table (3,196)
# help in table (3,197)
# help in table (3,198)
# help in table (3,199)
# help in table (3,200)
# help in table (3,201)
# help in table (3,202)
# help in table (3,203)
# help in table (3,204)
# help in table (3,205)
# help in table (3,206)
# help in table (3,207)
# help in table (3,208)
# help in table (3,209)
# help in table (3,210)
# help in table (3,211)
# help in table (3,212)
# help in table (3,213)
# help in table (3,214)
# help in table (3,215)
# help in table (3,216)
# help in table (3,217)
# help in table (3,218)
# help in table (3,219)
# help in table (3,220)
# help in table (3,221)
# help in table (3,222)
# help in table (3,223)
# help in table (3,224)
# help in table (3,225)
# help in table (3,226)
# help in table (3,227)
# help in table (3,228)
# help in table (3,229)
# help in table (3,230)
# help in table (3,231)
# help in table (3,232)
# help in table (3,233)
# help in table (3,234)
# help in table (3,235)
# help in table (3,236)
# help in table (3,237)
# help in table (3,238)
# help in table (4,1)
# help in table (4,2)
# help in table (4,3)
# help in table (4,4)
# help in table (4,5)
# help in table (4,6)
# help in table (4,7)
# help in table (4,8)
# help in table (4,9)
# help in table (4,10)
# help in table (4,11)
# help in table (4,12)
# help in table (4,13)
# help in table (4,14)
# help in table (4,15)
# help in table (4,16)
# help in table (4,17)
# help in table (4,18)
# help in table (4,19)
# help in table (4,20)
# help in table (4,21)
# help in table (4,22)
# help in table (4,23)
# help in table (4,24)
# help in table (4,25)
# help in table (4,26)
# help in table (4,27)
# help in table (4,28)
# help in table (4,29)
# help in table (4,30)
# help in table (4,31)
# help in table (4,32)
# help in table (4,33)
# help in table (4,34)
# help in table (4,35)
# help in table (4,36)
# help in table (4,37)
# help in table (4,38)
# help in table (4,39)
# help in table (4,40)
# help in table (4,41)
# help in table (4,42)
# help in table (4,43)
# help in table (4,44)
# help in table (4,45)
# help in table (4,46)
# help in table (4,47)
# help in table (4,48)
# help in table (4,49)
# help in table (4,50)
# help in table (4,51)
# help in table (4,52)
# help in table (4,53)
# help in table (4,54)
# help in table (4,55)
# help in table (4,56)
# help in table (4,57)
# help in table (4,58)
# help in table (4,59)
# help in table (4,60)
# help in table (4,61)
# help in table (4,62)
# help in table (4,63)
# help in table (4,64)
# help in table (4,65)
# help in table (4,66)
# help in table (4,67)
# help in table (4,68)
# help in table (4,69)
# help in table (4,70)
# help in table (4,71)
# help in table (4,72)
# help in table (4,73)
# help in table (4,74)
# help in table (4,75)
# help in table (4,76)
# help in table (4,77)
# help in table (4,78)
# help in table (4,79)
# help in table (4,80)
# help in table (4,81)
# help in table (4,82)
# help in table (4,83)
# help in table (4,84)
# help in table (4,85)
# help in table (4,86)
# help in table (4,87)
# help in table (4,88)
# help in table (4,89)
# help in table (4,90)
# help in table (4,91)
# help in table (4,92)
# help in table (4,93)
# help in table (4,94)
# help in table (4,95)
# help in table (4,96)
# help in table (4,97)
# help in table (4,98)
# help in table (4,99)
# help in table (4,100)
# help in table (4,101)
# help in table (4,102)
# help in table (4,103)
# help in table (4,104)
# help in table (4,105)
# help in table (4,106)
# help in table (4,107)
# help in table (4,108)
# help in table (4,109)
# help in table (4,110)
# help in table (4,111)
# help in table (4,112)
# help in table (4,113)
# help in table (4,114)
# help in table (4,115)
# help in table (4,116)
# help in table (4,117)
# help in table (4,118)
# help in table (4,119)
# help in table (4,120)
# help in table (4,121)
# help in table (4,122)
# help in table (4,123)
# help in table (4,124)
# help in table (4,125)
# help in table (4,126)
# help in table (4,127)
# help in table (4,128)
# help in table (4,129)
# help in table (4,130)
# help in table (4,131)
# help in table (4,132)
# help in table (4,133)
# help in table (4,134)
# help in table (4,135)
# help in table (4,136)
# help in table (4,137)
# help in table (4,138)
# help in table (4,139)
# help in table (4,140)
# help in table (4,141)
# help in table (4,142)
# help in table (4,143)
# help in table (4,144)
# help in table (4,145)
# help in table (4,146)
# help in table (4,147)
# help in table (4,148)
# help in table (4,149)
# help in table (4,150)
# help in table (4,151)
# help in table (4,152)
# help in table (4,153)
# help in table (4,154)
# help in table (4,155)
# help in table (4,156)
# help in table (4,157)
# help in table (4,158)
# help in table (4,159)
# help in table (4,160)
# help in table (4,161)
# help in table (4,162)
# help in table (4,163)
# help in table (4,164)
# help in table (4,165)
# help in table (4,166)
# help in table (4,167)
# help in table (4,168)
# help in table (4,169)
# help in table (4,170)
# help in table (4,171)
# help in table (4,172)
# help in table (4,173)
# help in table (4,174)
# help in table (4,175)
# help in table (4,176)
# help in table (4,177)
# help in table (4,178)
# help in table (4,179)
# help in table (4,180)
# help in table (4,181)
# help in table (4,182)
# help in table (4,183)
# help in table (4,184)
# help in table (4,185)
# help in table (4,186)
# help in table (4,187)
# help in table (4,188)
# help in table (4,189)
# help in table (4,190)
# help in table (4,191)
# help in table (4,192)
# help in table (4,193)
# help in table (4,194)
# help in table (4,195)
# help in table (4,196)
# help in table (4,197)
# help in table (4,198)
# help in table (4,199)
# help in table (4,200)
# help in table (4,201)
# help in table (4,202)
# help in table (4,203)
# help in table (4,204)
# help in table (4,205)
# help in table (4,206)
# help in table (4,207)
# help in table (4,208)
# help in table (4,209)
# help in table (4,210)
# help in table (4,211)
# help in table (4,212)
# help in table (4,213)
# help in table (4,214)
# help in table (4,215)
# help in table (4,216)
# help in table (4,217)
# help in table (4,218)
# help in table (4,219)
# help in table (4,220)
# help in table (4,221)
# help in table (4,222)
# help in table (4,223)
# help in table (4,224)
# help in table (4,225)
# help in table (4,226)
# help in table (4,227)
# help in table (4,228)
# help in table (4,229)
# help in table (4,230)
# help in table (4,231)
# help in table (4,232)
# help in table (4,233)
# help in table (4,234)
# help in table (4,235)
# help in table (4,236)
# help in table (4,237)
# help in table (4,238)
# help in table (5,1)
# help in table (5,2)
# help in table (5,3)
# help in table (5,4)
# help in table (5,5)
# help in table (5,6)
# help in table (5,7)
# help in table (5,8)
# help in table (5,9)
# help in table (5,10)
# help in table (5,11)
# help in table (5,12)
# help in table (5,13)
# help in table (5,14)
# help in table (5,15)
# help in table (5,16)
# help in table (5,17)
# help in table (5,18)
# help in table (5,19)
# help in table (5,20)
# help in table (5,21)
# help in table (5,22)
# help in table (5,23)
# help in table (5,24)
# help in table (5,25)
# help in table (5,26)
# help in table (5,27)
# help in table (5,28)
# help in table (5,29)
# help in table (5,30)
# help in table (5,31)
# help in table (5,32)
# help in table (5,33)
# help in table (5,34)
# help in table (5,35)
# help in table (5,36)
# help in table (5,37)
# help in table (5,38)
# help in table (5,39)
# help in table (5,40)
# help in table (5,41)
# help in table (5,42)
# help in table (5,43)
# help in table (5,44)
# help in table (5,45)
# help in table (5,46)
# help in table (5,47)
# help in table (5,48)
# help in table (5,49)
# help in table (5,50)
# help in table (5,51)
# help in table (5,52)
# help in table (5,53)
# help in table (5,54)
# help in table (5,55)
# help in table (5,56)
# help in table (5,57)
# help in table (5,58)
# help in table (5,59)
# help in table (5,60)
# help in table (5,61)
# help in table (5,62)
# help in table (5,63)
# help in table (5,64)
# help in table (5,65)
# help in table (5,66)
# help in table (5,67)
# help in table (5,68)
# help in table (5,69)
# help in table (5,70)
# help in table (5,71)
# help in table (5,72)
# help in table (5,73)
# help in table (5,74)
# help in table (5,75)
# help in table (5,76)
# help in table (5,77)
# help in table (5,78)
# help in table (5,79)
# help in table (5,80)
# help in table (5,81)
# help in table (5,82)
# help in table (5,83)
# help in table (5,84)
# help in table (5,85)
# help in table (5,86)
# help in table (5,87)
# help in table (5,88)
# help in table (5,89)
# help in table (5,90)
# help in table (5,91)
# help in table (5,92)
# help in table (5,93)
# help in table (5,94)
# help in table (5,95)
# help in table (5,96)
# help in table (5,97)
# help in table (5,98)
# help in table (5,99)
# help in table (5,100)
# help in table (5,101)
# help in table (5,102)
# help in table (5,103)
# help in table (5,104)
# help in table (5,105)
# help in table (5,106)
# help in table (5,107)
# help in table (5,108)
# help in table (5,109)
# help in table (5,110)
# help in table (5,111)
# help in table (5,112)
# help in table (5,113)
# help in table (5,114)
# help in table (5,115)
# help in table (5,116)
# help in table (5,117)
# help in table (5,118)
# help in table (5,119)
# help in table (5,120)
# help in table (5,121)
# help in table (5,122)
# help in table (5,123)
# help in table (5,124)
# help in table (5,125)
# help in table (5,126)
# help in table (5,127)
# help in table (5,128)
# help in table (5,129)
# help in table (5,130)
# help in table (5,131)
# help in table (5,132)
# help in table (5,133)
# help in table (5,134)
# help in table (5,135)
# help in table (5,136)
# help in table (5,137)
# help in table (5,138)
# help in table (5,139)
# help in table (5,140)
# help in table (5,141)
# help in table (5,142)
# help in table (5,143)
# help in table (5,144)
# help in table (5,145)
# help in table (5,146)
# help in table (5,147)
# help in table (5,148)
# help in table (5,149)
# help in table (5,150)
# help in table (5,151)
# help in table (5,152)
# help in table (5,153)
# help in table (5,154)
# help in table (5,155)
# help in table (5,156)
# help in table (5,157)
# help in table (5,158)
# help in table (5,159)
# help in table (5,160)
# help in table (5,161)
# help in table (5,162)
# help in table (5,163)
# help in table (5,164)
# help in table (5,165)
# help in table (5,166)
# help in table (5,167)
# help in table (5,168)
# help in table (5,169)
# help in table (5,170)
# help in table (5,171)
# help in table (5,172)
# help in table (5,173)
# help in table (5,174)
# help in table (5,175)
# help in table (5,176)
# help in table (5,177)
# help in table (5,178)
# help in table (5,179)
# help in table (5,180)
# help in table (5,181)
# help in table (5,182)
# help in table (5,183)
# help in table (5,184)
# help in table (5,185)
# help in table (5,186)
# help in table (5,187)
# help in table (5,188)
# help in table (5,189)
# help in table (5,190)
# help in table (5,191)
# help in table (5,192)
# help in table (5,193)
# help in table (5,194)
# help in table (5,195)
# help in table (5,196)
# help in table (5,197)
# help in table (5,198)
# help in table (5,199)
# help in table (5,200)
# help in table (5,201)
# help in table (5,202)
# help in table (5,203)
# help in table (5,204)
# help in table (5,205)
# help in table (5,206)
# help in table (5,207)
# help in table (5,208)
# help in table (5,209)
# help in table (5,210)
# help in table (5,211)
# help in table (5,212)
# help in table (5,213)
# help in table (5,214)
# help in table (5,215)
# help in table (5,216)
# help in table (5,217)
# help in table (5,218)
# help in table (5,219)
# help in table (5,220)
# help in table (5,221)
# help in table (5,222)
# help in table (5,223)
# help in table (5,224)
# help in table (5,225)
# help in table (5,226)
# help in table (5,227)
# help in table (5,228)
# help in table (5,229)
# help in table (5,230)
# help in table (5,231)
# help in table (5,232)
# help in table (5,233)
# help in table (5,234)
# help in table (5,235)
# help in table (5,236)
# help in table (5,237)
# help in table (5,238)
# help in table (6,1)
# help in table (6,2)
# help in table (6,3)
# help in table (6,4)
# help in table (6,5)
# help in table (6,6)
# help in table (6,7)
# help in table (6,8)
# help in table (6,9)
# help in table (6,10)
# help in table (6,11)
# help in table (6,12)
# help in table (6,13)
# help in table (6,14)
# help in table (6,15)
# help in table (6,16)
# help in table (6,17)
# help in table (6,18)
# help in table (6,19)
# help in table (6,20)
# help in table (6,21)
# help in table (6,22)
# help in table (6,23)
# help in table (6,24)
# help in table (6,25)
# help in table (6,26)
# help in table (6,27)
# help in table (6,28)
# help in table (6,29)
# help in table (6,30)
# help in table (6,31)
# help in table (6,32)
# help in table (6,33)
# help in table (6,34)
# help in table (6,35)
# help in table (6,36)
# help in table (6,37)
# help in table (6,38)
# help in table (6,39)
# help in table (6,40)
# help in table (6,41)
# help in table (6,42)
# help in table (6,43)
# help in table (6,44)
# help in table (6,45)
# help in table (6,46)
# help in table (6,47)
# help in table (6,48)
# help in table (6,49)
# help in table (6,50)
# help in table (6,51)
# help in table (6,52)
# help in table (6,53)
# help in table (6,54)
# help in table (6,55)
# help in table (6,56)
# help in table (6,57)
# help in table (6,58)
# help in table (6,59)
# help in table (6,60)
# help in table (6,61)
# help in table (6,62)
# help in table (6,63)
# help in table (6,64)
# help in table (6,65)
# help in table (6,66)
# help in table (6,67)
# help in table (6,68)
# help in table (6,69)
# help in table (6,70)
# help in table (6,71)
# help in table (6,72)
# help in table (6,73)
# help in table (6,74)
# help in table (6,75)
# help in table (6,76)
# help in table (6,77)
# help in table (6,78)
# help in table (6,79)
# help in table (6,80)
# help in table (6,81)
# help in table (6,82)
# help in table (6,83)
# help in table (6,84)
# help in table (6,85)
# help in table (6,86)
# help in table (6,87)
# help in table (6,88)
# help in table (6,89)
# help in table (6,90)
# help in table (6,91)
# help in table (6,92)
# help in table (6,93)
# help in table (6,94)
# help in table (6,95)
# help in table (6,96)
# help in table (6,97)
# help in table (6,98)
# help in table (6,99)
# help in table (6,100)
# help in table (6,101)
# help in table (6,102)
# help in table (6,103)
# help in table (6,104)
# help in table (6,105)
# help in table (6,106)
# help in table (6,107)
# help in table (6,108)
# help in table (6,109)
# help in table (6,110)
# help in table (6,111)
# help in table (6,112)
# help in table (6,113)
# help in table (6,114)
# help in table (6,115)
# help in table (6,116)
# help in table (6,117)
# help in table (6,118)
# help in table (6,119)
# help in table (6,120)
# help in table (6,121)
# help in table (6,122)
# help in table (6,123)
# help in table (6,124)
# help in table (6,125)
# help in table (6,126)
# help in table (6,127)
# help in table (6,128)
# help in table (6,129)
# help in table (6,130)
# help in table (6,131)
# help in table (6,132)
# help in table (6,133)
# help in table (6,134)
# help in table (6,135)
# help in table (6,136)
# help in table (6,137)
# help in table (6,138)
# help in table (6,139)
# help in table (6,140)
# help in table (6,141)
# help in table (6,142)
# help in table (6,143)
# help in table (6,144)
# help in table (6,145)
# help in table (6,146)
# help in table (6,147)
# help in table (6,148)
# help in table (6,149)
# help in table (6,150)
# help in table (6,151)
# help in table (6,152)
# help in table (6,153)
# help in table (6,154)
# help in table (6,155)
# help in table (6,156)
# help in table (6,157)
# help in table (6,158)
# help in table (6,159)
# help in table (6,160)
# help in table (6,161)
# help in table (6,162)
# help in table (6,163)
# help in table (6,164)
# help in table (6,165)
# help in table (6,166)
# help in table (6,167)
# help in table (6,168)
# help in table (6,169)
# help in table (6,170)
# help in table (6,171)
# help in table (6,172)
# help in table (6,173)
# help in table (6,174)
# help in table (6,175)
# help in table (6,176)
# help in table (6,177)
# help in table (6,178)
# help in table (6,179)
# help in table (6,180)
# help in table (6,181)
# help in table (6,182)
# help in table (6,183)
# help in table (6,184)
# help in table (6,185)
# help in table (6,186)
# help in table (6,187)
# help in table (6,188)
# help in table (6,189)
# help in table (6,190)
# help in table (6,191)
# help in table (6,192)
# help in table (6,193)
# help in table (6,194)
# help in table (6,195)
# help in table (6,196)
# help in table (6,197)
# help in table (6,198)
# help in table (6,199)
# help in table (6,200)
# help in table (6,201)
# help in table (6,202)
# help in table (6,203)
# help in table (6,204)
# help in table (6,205)
# help in table (6,206)
# help in table (6,207)
# help in table (6,208)
# help in table (6,209)
# help in table (6,210)
# help in table (6,211)
# help in table (6,212)
# help in table (6,213)
# help in table (6,214)
# help in table (6,215)
# help in table (6,216)
# help in table (6,217)
# help in table (6,218)
# help in table (6,219)
# help in table (6,220)
# help in table (6,221)
# help in table (6,222)
# help in table (6,223)
# help in table (6,224)
# help in table (6,225)
# help in table (6,226)
# help in table (6,227)
# help in table (6,228)
# help in table (6,229)
# help in table (6,230)
# help in table (6,231)
# help in table (6,232)
# help in table (6,233)
# help in table (6,234)
# help in table (6,235)
# help in table (6,236)
# help in table (6,237)
# help in table (6,238)
# help in table (7,1)
# help in table (7,2)
# help in table (7,3)
# help in table (7,4)
# help in table (7,5)
# help in table (7,6)
# help in table (7,7)
# help in table (7,8)
# help in table (7,9)
# help in table (7,10)
# help in table (7,11)
# help in table (7,12)
# help in table (7,13)
# help in table (7,14)
# help in table (7,15)
# help in table (7,16)
# help in table (7,17)
# help in table (7,18)
# help in table (7,19)
# help in table (7,20)
# help in table (7,21)
# help in table (7,22)
# help in table (7,23)
# help in table (7,24)
# help in table (7,25)
# help in table (7,26)
# help in table (7,27)
# help in table (7,28)
# help in table (7,29)
# help in table (7,30)
# help in table (7,31)
# help in table (7,32)
# help in table (7,33)
# help in table (7,34)
# help in table (7,35)
# help in table (7,36)
# help in table (7,37)
# help in table (7,38)
# help in table (7,39)
# help in table (7,40)
# help in table (7,41)
# help in table (7,42)
# help in table (7,43)
# help in table (7,44)
# help in table (7,45)
# help in table (7,46)
# help in table (7,47)
# help in table (7,48)
# help in table (7,49)
# help in table (7,50)
# help in table (7,51)
# help in table (7,52)
# help in table (7,53)
# help in table (7,54)
# help in table (7,55)
# help in table (7,56)
# help in table (7,57)
# help in table (7,58)
# help in table (7,59)
# help in table (7,60)
# help in table (7,61)
# help in table (7,62)
# help in table (7,63)
# help in table (7,64)
# help in table (7,65)
# help in table (7,66)
# help in table (7,67)
# help in table (7,68)
# help in table (7,69)
# help in table (7,70)
# help in table (7,71)
# help in table (7,72)
# help in table (7,73)
# help in table (7,74)
# help in table (7,75)
# help in table (7,76)
# help in table (7,77)
# help in table (7,78)
# help in table (7,79)
# help in table (7,80)
# help in table (7,81)
# help in table (7,82)
# help in table (7,83)
# help in table (7,84)
# help in table (7,85)
# help in table (7,86)
# help in table (7,87)
# help in table (7,88)
# help in table (7,89)
# help in table (7,90)
# help in table (7,91)
# help in table (7,92)
# help in table (7,93)
# help in table (7,94)
# help in table (7,95)
# help in table (7,96)
# help in table (7,97)
# help in table (7,98)
# help in table (7,99)
# help in table (7,100)
# help in table (7,101)
# help in table (7,102)
# help in table (7,103)
# help in table (7,104)
# help in table (7,105)
# help in table (7,106)
# help in table (7,107)
# help in table (7,108)
# help in table (7,109)
# help in table (7,110)
# help in table (7,111)
# help in table (7,112)
# help in table (7,113)
# help in table (7,114)
# help in table (7,115)
# help in table (7,116)
# help in table (7,117)
# help in table (7,118)
# help in table (7,119)
# help in table (7,120)
# help in table (7,121)
# help in table (7,122)
# help in table (7,123)
# help in table (7,124)
# help in table (7,125)
# help in table (7,126)
# help in table (7,127)
# help in table (7,128)
# help in table (7,129)
# help in table (7,130)
# help in table (7,131)
# help in table (7,132)
# help in table (7,133)
# help in table (7,134)
# help in table (7,135)
# help in table (7,136)
# help in table (7,137)
# help in table (7,138)
# help in table (7,139)
# help in table (7,140)
# help in table (7,141)
# help in table (7,142)
# help in table (7,143)
# help in table (7,144)
# help in table (7,145)
# help in table (7,146)
# help in table (7,147)
# help in table (7,148)
# help in table (7,149)
# help in table (7,150)
# help in table (7,151)
# help in table (7,152)
# help in table (7,153)
# help in table (7,154)
# help in table (7,155)
# help in table (7,156)
# help in table (7,157)
# help in table (7,158)
# help in table (7,159)
# help in table (7,160)
# help in table (7,161)
# help in table (7,162)
# help in table (7,163)
# help in table (7,164)
# help in table (7,165)
# help in table (7,166)
# help in table (7,167)
# help in table (7,168)
# help in table (7,169)
# help in table (7,170)
# help in table (7,171)
# help in table (7,172)
# help in table (7,173)
# help in table (7,174)
# help in table (7,175)
# help in table (7,176)
# help in table (7,177)
# help in table (7,178)
# help in table (7,179)
# help in table (7,180)
# help in table (7,181)
# help in table (7,182)
# help in table (7,183)
# help in table (7,184)
# help in table (7,185)
# help in table (7,186)
# help in table (7,187)
# help in table (7,188)
# help in table (7,189)
# help in table (7,190)
# help in table (7,191)
# help in table (7,192)
# help in table (7,193)
# help in table (7,194)
# help in table (7,195)
# help in table (7,196)
# help in table (7,197)
# help in table (7,198)
# help in table (7,199)
# help in table (7,200)
# help in table (7,201)
# help in table (7,202)
# help in table (7,203)
# help in table (7,204)
# help in table (7,205)
# help in table (7,206)
# help in table (7,207)
# help in table (7,208)
# help in table (7,209)
# help in table (7,210)
# help in table (7,211)
# help in table (7,212)
# help in table (7,213)
# help in table (7,214)
# help in table (7,215)
# help in table (7,216)
# help in table (7,217)
# help in table (7,218)
# help in table (7,219)
# help in table (7,220)
# help in table (7,221)
# help in table (7,222)
# help in table (7,223)
# help in table (7,224)
# help in table (7,225)
# help in table (7,226)
# help in table (7,227)
# help in table (7,228)
# help in table (7,229)
# help in table (7,230)
# help in table (7,231)
# help in table (7,232)
# help in table (7,233)
# help in table (7,234)
# help in table (7,235)
# help in table (7,236)
# help in table (7,237)
# help in table (7,238)
# help in table (8,1)
# help in table (8,2)
# help in table (8,3)
# help in table (8,4)
# help in table (8,5)
# help in table (8,6)
# help in table (8,7)
# help in table (8,8)
# help in table (8,9)
# help in table (8,10)
# help in table (8,11)
# help in table (8,12)
# help in table (8,13)
# help in table (8,14)
# help in table (8,15)
# help in table (8,16)
# help in table (8,17)
# help in table (8,18)
# help in table (8,19)
# help in table (8,20)
# help in table (8,21)
# help in table (8,22)
# help in table (8,23)
# help in table (8,24)
# help in table (8,25)
# help in table (8,26)
# help in table (8,27)
# help in table (8,28)
# help in table (8,29)
# help in table (8,30)
# help in table (8,31)
# help in table (8,32)
# help in table (8,33)
# help in table (8,34)
# help in table (8,35)
# help in table (8,36)
# help in table (8,37)
# help in table (8,38)
# help in table (8,39)
# help in table (8,40)
# help in table (8,41)
# help in table (8,42)
# help in table (8,43)
# help in table (8,44)
# help in table (8,45)
# help in table (8,46)
# help in table (8,47)
# help in table (8,48)
# help in table (8,49)
# help in table (8,50)
# help in table (8,51)
# help in table (8,52)
# help in table (8,53)
# help in table (8,54)
# help in table (8,55)
# help in table (8,56)
# help in table (8,57)
# help in table (8,58)
# help in table (8,59)
# help in table (8,60)
# help in table (8,61)
# help in table (8,62)
# help in table (8,63)
# help in table (8,64)
# help in table (8,65)
# help in table (8,66)
# help in table (8,67)
# help in table (8,68)
# help in table (8,69)
# help in table (8,70)
# help in table (8,71)
# help in table (8,72)
# help in table (8,73)
# help in table (8,74)
# help in table (8,75)
# help in table (8,76)
# help in table (8,77)
# help in table (8,78)
# help in table (8,79)
# help in table (8,80)
# help in table (8,81)
# help in table (8,82)
# help in table (8,83)
# help in table (8,84)
# help in table (8,85)
# help in table (8,86)
# help in table (8,87)
# help in table (8,88)
# help in table (8,89)
# help in table (8,90)
# help in table (8,91)
# help in table (8,92)
# help in table (8,93)
# help in table (8,94)
# help in table (8,95)
# help in table (8,96)
# help in table (8,97)
# help in table (8,98)
# help in table (8,99)
# help in table (8,100)
# help in table (8,101)
# help in table (8,102)
# help in table (8,103)
# help in table (8,104)
# help in table (8,105)
# help in table (8,106)
# help in table (8,107)
# help in table (8,108)
# help in table (8,109)
# help in table (8,110)
# help in table (8,111)
# help in table (8,112)
# help in table (8,113)
# help in table (8,114)
# help in table (8,115)
# help in table (8,116)
# help in table (8,117)
# help in table (8,118)
# help in table (8,119)
# help in table (8,120)
# help in table (8,121)
# help in table (8,122)
# help in table (8,123)
# help in table (8,124)
# help in table (8,125)
# help in table (8,126)
# help in table (8,127)
# help in table (8,128)
# help in table (8,129)
# help in table (8,130)
# help in table (8,131)
# help in table (8,132)
# help in table (8,133)
# help in table (8,134)
# help in table (8,135)
# help in table (8,136)
# help in table (8,137)
# help in table (8,138)
# help in table (8,139)
# help in table (8,140)
# help in table (8,141)
# help in table (8,142)
# help in table (8,143)
# help in table (8,144)
# help in table (8,145)
# help in table (8,146)
# help in table (8,147)
# help in table (8,148)
# help in table (8,149)
# help in table (8,150)
# help in table (8,151)
# help in table (8,152)
# help in table (8,153)
# help in table (8,154)
# help in table (8,155)
# help in table (8,156)
# help in table (8,157)
# help in table (8,158)
# help in table (8,159)
# help in table (8,160)
# help in table (8,161)
# help in table (8,162)
# help in table (8,163)
# help in table (8,164)
# help in table (8,165)
# help in table (8,166)
# help in table (8,167)
# help in table (8,168)
# help in table (8,169)
# help in table (8,170)
# help in table (8,171)
# help in table (8,172)
# help in table (8,173)
# help in table (8,174)
# help in table (8,175)
# help in table (8,176)
# help in table (8,177)
# help in table (8,178)
# help in table (8,179)
# help in table (8,180)
# help in table (8,181)
# help in table (8,182)
# help in table (8,183)
# help in table (8,184)
# help in table (8,185)
# help in table (8,186)
# help in table (8,187)
# help in table (8,188)
# help in table (8,189)
# help in table (8,190)
# help in table (8,191)
# help in table (8,192)
# help in table (8,193)
# help in table (8,194)
# help in table (8,195)
# help in table (8,196)
# help in table (8,197)
# help in table (8,198)
# help in table (8,199)
# help in table (8,200)
# help in table (8,201)
# help in table (8,202)
# help in table (8,203)
# help in table (8,204)
# help in table (8,205)
# help in table (8,206)
# help in table (8,207)
# help in table (8,208)
# help in table (8,209)
# help in table (8,210)
# help in table (8,211)
# help in table (8,212)
# help in table (8,213)
# help in table (8,214)
# help in table (8,215)
# help in table (8,216)
# help in table (8,217)
# help in table (8,218)
# help in table (8,219)
# help in table (8,220)
# help in table (8,221)
# help in table (8,222)
# help in table (8,223)
# help in table (8,224)
# help in table (8,225)
# help in table (8,226)
# help in table (8,227)
# help in table (8,228)
# help in table (8,229)
# help in table (8,230)
# help in table (8,231)
# help in table (8,232)
# help in table (8,233)
# help in table (8,234)
# help in table (8,235)
# help in table (8,236)
# help in table (8,237)
# help in table (8,238)
# help in table (9,1)
# help in table (9,2)
# help in table (9,3)
# help in table (9,4)
# help in table (9,5)
# help in table (9,6)
# help in table (9,7)
# help in table (9,8)
# help in table (9,9)
# help in table (9,10)
# help in table (9,11)
# help in table (9,12)
# help in table (9,13)
# help in table (9,14)
# help in table (9,15)
# help in table (9,16)
# help in table (9,17)
# help in table (9,18)
# help in table (9,19)
# help in table (9,20)
# help in table (9,21)
# help in table (9,22)
# help in table (9,23)
# help in table (9,24)
# help in table (9,25)
# help in table (9,26)
# help in table (9,27)
# help in table (9,28)
# help in table (9,29)
# help in table (9,30)
# help in table (9,31)
# help in table (9,32)
# help in table (9,33)
# help in table (9,34)
# help in table (9,35)
# help in table (9,36)
# help in table (9,37)
# help in table (9,38)
# help in table (9,39)
# help in table (9,40)
# help in table (9,41)
# help in table (9,42)
# help in table (9,43)
# help in table (9,44)
# help in table (9,45)
# help in table (9,46)
# help in table (9,47)
# help in table (9,48)
# help in table (9,49)
# help in table (9,50)
# help in table (9,51)
# help in table (9,52)
# help in table (9,53)
# help in table (9,54)
# help in table (9,55)
# help in table (9,56)
# help in table (9,57)
# help in table (9,58)
# help in table (9,59)
# help in table (9,60)
# help in table (9,61)
# help in table (9,62)
# help in table (9,63)
# help in table (9,64)
# help in table (9,65)
# help in table (9,66)
# help in table (9,67)
# help in table (9,68)
# help in table (9,69)
# help in table (9,70)
# help in table (9,71)
# help in table (9,72)
# help in table (9,73)
# help in table (9,74)
# help in table (9,75)
# help in table (9,76)
# help in table (9,77)
# help in table (9,78)
# help in table (9,79)
# help in table (9,80)
# help in table (9,81)
# help in table (9,82)
# help in table (9,83)
# help in table (9,84)
# help in table (9,85)
# help in table (9,86)
# help in table (9,87)
# help in table (9,88)
# help in table (9,89)
# help in table (9,90)
# help in table (9,91)
# help in table (9,92)
# help in table (9,93)
# help in table (9,94)
# help in table (9,95)
# help in table (9,96)
# help in table (9,97)
# help in table (9,98)
# help in table (9,99)
# help in table (9,100)
# help in table (9,101)
# help in table (9,102)
# help in table (9,103)
# help in table (9,104)
# help in table (9,105)
# help in table (9,106)
# help in table (9,107)
# help in table (9,108)
# help in table (9,109)
# help in table (9,110)
# help in table (9,111)
# help in table (9,112)
# help in table (9,113)
# help in table (9,114)
# help in table (9,115)
# help in table (9,116)
# help in table (9,117)
# help in table (9,118)
# help in table (9,119)
# help in table (9,120)
# help in table (9,121)
# help in table (9,122)
# help in table (9,123)
# help in table (9,124)
# help in table (9,125)
# help in table (9,126)
# help in table (9,127)
# help in table (9,128)
# help in table (9,129)
# help in table (9,130)
# help in table (9,131)
# help in table (9,132)
# help in table (9,133)
# help in table (9,134)
# help in table (9,135)
# help in table (9,136)
# help in table (9,137)
# help in table (9,138)
# help in table (9,139)
# help in table (9,140)
# help in table (9,141)
# help in table (9,142)
# help in table (9,143)
# help in table (9,144)
# help in table (9,145)
# help in table (9,146)
# help in table (9,147)
# help in table (9,148)
# help in table (9,149)
# help in table (9,150)
# help in table (9,151)
# help in table (9,152)
# help in table (9,153)
# help in table (9,154)
# help in table (9,155)
# help in table (9,156)
# help in table (9,157)
# help in table (9,158)
# help in table (9,159)
# help in table (9,160)
# help in table (9,161)
# help in table (9,162)
# help in table (9,163)
# help in table (9,164)
# help in table (9,165)
# help in table (9,166)
# help in table (9,167)
# help in table (9,168)
# help in table (9,169)
# help in table (9,170)
# help in table (9,171)
# help in table (9,172)
# help in table (9,173)
# help in table (9,174)
# help in table (9,175)
# help in table (9,176)
# help in table (9,177)
# help in table (9,178)
# help in table (9,179)
# help in table (9,180)
# help in table (9,181)
# help in table (9,182)
# help in table (9,183)
# help in table (9,184)
# help in table (9,185)
# help in table (9,186)
# help in table (9,187)
# help in table (9,188)
# help in table (9,189)
# help in table (9,190)
# help in table (9,191)
# help in table (9,192)
# help in table (9,193)
# help in table (9,194)
# help in table (9,195)
# help in table (9,196)
# help in table (9,197)
# help in table (9,198)
# help in table (9,199)
# help in table (9,200)
# help in table (9,201)
# help in table (9,202)
# help in table (9,203)
# help in table (9,204)
# help in table (9,205)
# help in table (9,206)
# help in table (9,207)
# help in table (9,208)
# help in table (9,209)
# help in table (9,210)
# help in table (9,211)
# help in table (9,212)
# help in table (9,213)
# help in table (9,214)
# help in table (9,215)
# help in table (9,216)
# help in table (9,217)
# help in table (9,218)
# help in table (9,219)
# help in table (9,220)
# help in table (9,221)
# help in table (9,222)
# help in table (9,223)
# help in table (9,224)
# help in table (9,225)
# help in table (9,226)
# help in table (9,227)
# help in table (9,228)
# help in table (9,229)
# help in table (9,230)
# help in table (9,231)
# help in table (9,232)
# help in table (9,233)
# help in table (9,234)
# help in table (9,235)
# help in table (9,236)
# help in table (9,237)
# help in table (9,238)
# help in table (10,1)
# help in table (10,2)
# help in table (10,3)
# help in table (10,4)
# help in table (10,5)
# help in table (10,6)
# help in table (10,7)
# help in table (10,8)
# help in table (10,9)
# help in table (10,10)
# help in table (10,11)
# help in table (10,12)
# help in table (10,13)
# help in table (10,14)
# help in table (10,15)
# help in table (10,16)
# help in table (10,17)
# help in table (10,18)
# help in table (10,19)
# help in table (10,20)
# help in table (10,21)
# help in table (10,22)
# help in table (10,23)
# help in table (10,24)
# help in table (10,25)
# help in table (10,26)
# help in table (10,27)
# help in table (10,28)
# help in table (10,29)
# help in table (10,30)
# help in table (10,31)
# help in table (10,32)
# help in table (10,33)
# help in table (10,34)
# help in table (10,35)
# help in table (10,36)
# help in table (10,37)
# help in table (10,38)
# help in table (10,39)
# help in table (10,40)
# help in table (10,41)
# help in table (10,42)
# help in table (10,43)
# help in table (10,44)
# help in table (10,45)
# help in table (10,46)
# help in table (10,47)
# help in table (10,48)
# help in table (10,49)
# help in table (10,50)
# help in table (10,51)
# help in table (10,52)
# help in table (10,53)
# help in table (10,54)
# help in table (10,55)
# help in table (10,56)
# help in table (10,57)
# help in table (10,58)
# help in table (10,59)
# help in table (10,60)
# help in table (10,61)
# help in table (10,62)
# help in table (10,63)
# help in table (10,64)
# help in table (10,65)
# help in table (10,66)
# help in table (10,67)
# help in table (10,68)
# help in table (10,69)
# help in table (10,70)
# help in table (10,71)
# help in table (10,72)
# help in table (10,73)
# help in table (10,74)
# help in table (10,75)
# help in table (10,76)
# help in table (10,77)
# help in table (10,78)
# help in table (10,79)
# help in table (10,80)
# help in table (10,81)
# help in table (10,82)
# help in table (10,83)
# help in table (10,84)
# help in table (10,85)
# help in table (10,86)
# help in table (10,87)
# help in table (10,88)
# help in table (10,89)
# help in table (10,90)
# help in table (10,91)
# help in table (10,92)
# help in table (10,93)
# help in table (10,94)
# help in table (10,95)
# help in table (10,96)
# help in table (10,97)
# help in table (10,98)
# help in table (10,99)
# help in table (10,100)
# help in table (10,101)
# help in table (10,102)
# help in table (10,103)
# help in table (10,104)
# help in table (10,105)
# help in table (10,106)
# help in table (10,107)
# help in table (10,108)
# help in table (10,109)
# help in table (10,110)
# help in table (10,111)
# help in table (10,112)
# help in table (10,113)
# help in table (10,114)
# help in table (10,115)
# help in table (10,116)
# help in table (10,117)
# help in table (10,118)
# help in table (10,119)
# help in table (10,120)
# help in table (10,121)
# help in table (10,122)
# help in table (10,123)
# help in table (10,124)
# help in table (10,125)
# help in table (10,126)
# help in table (10,127)
# help in table (10,128)
# help in table (10,129)
# help in table (10,130)
# help in table (10,131)
# help in table (10,132)
# help in table (10,133)
# help in table (10,134)
# help in table (10,135)
# help in table (10,136)
# help in table (10,137)
# help in table (10,138)
# help in table (10,139)
# help in table (10,140)
# help in table (10,141)
# help in table (10,142)
# help in table (10,143)
# help in table (10,144)
# help in table (10,145)
# help in table (10,146)
# help in table (10,147)
# help in table (10,148)
# help in table (10,149)
# help in table (10,150)
# help in table (10,151)
# help in table (10,152)
# help in table (10,153)
# help in table (10,154)
# help in table (10,155)
# help in table (10,156)
# help in table (10,157)
# help in table (10,158)
# help in table (10,159)
# help in table (10,160)
# help in table (10,161)
# help in table (10,162)
# help in table (10,163)
# help in table (10,164)
# help in table (10,165)
# help in table (10,166)
# help in table (10,167)
# help in table (10,168)
# help in table (10,169)
# help in table (10,170)
# help in table (10,171)
# help in table (10,172)
# help in table (10,173)
# help in table (10,174)
# help in table (10,175)
# help in table (10,176)
# help in table (10,177)
# help in table (10,178)
# help in table (10,179)
# help in table (10,180)
# help in table (10,181)
# help in table (10,182)
# help in table (10,183)
# help in table (10,184)
# help in table (10,185)
# help in table (10,186)
# help in table (10,187)
# help in table (10,188)
# help in table (10,189)
# help in table (10,190)
# help in table (10,191)
# help in table (10,192)
# help in table (10,193)
# help in table (10,194)
# help in table (10,195)
# help in table (10,196)
# help in table (10,197)
# help in table (10,198)
# help in table (10,199)
# help in table (10,200)
# help in table (10,201)
# help in table (10,202)
# help in table (10,203)
# help in table (10,204)
# help in table (10,205)
# help in table (10,206)
# help in table (10,207)
# help in table (10,208)
# help in table (10,209)
# help in table (10,210)
# help in table (10,211)
# help in table (10,212)
# help in table (10,213)
# help in table (10,214)
# help in table (10,215)
# help in table (10,216)
# help in table (10,217)
# help in table (10,218)
# help in table (10,219)
# help in table (10,220)
# help in table (10,221)
# help in table (10,222)
# help in table (10,223)
# help in table (10,224)
# help in table (10,225)
# help in table (10,226)
# help in table (10,227)
# help in table (10,228)
# help in table (10,229)
# help in table (10,230)
# help in table (10,231)
# help in table (10,232)
# help in table (10,233)
# help in table (10,234)
# help in table (10,235)
# help in table (10,236)
# help in table (10,237)
# help in table (10,238)
# help in table (11,1)
# help in table (11,2)
# help in table (11,3)
# help in table (11,4)
# help in table (11,5)
# help in table (11,6)
# help in table (11,7)
# help in table (11,8)
# help in table (11,9)
# help in table (11,10)
# help in table (11,11)
# help in table (11,12)
# help in table (11,13)
# help in table (11,14)
# help in table (11,15)
# help in table (11,16)
# help in table (11,17)
# help in table (11,18)
# help in table (11,19)
# help in table (11,20)
# help in table (11,21)
# help in table (11,22)
# help in table (11,23)
# help in table (11,24)
# help in table (11,25)
# help in table (11,26)
# help in table (11,27)
# help in table (11,28)
# help in table (11,29)
# help in table (11,30)
# help in table (11,31)
# help in table (11,32)
# help in table (11,33)
# help in table (11,34)
# help in table (11,35)
# help in table (11,36)
# help in table (11,37)
# help in table (11,38)
# help in table (11,39)
# help in table (11,40)
# help in table (11,41)
# help in table (11,42)
# help in table (11,43)
# help in table (11,44)
# help in table (11,45)
# help in table (11,46)
# help in table (11,47)
# help in table (11,48)
# help in table (11,49)
# help in table (11,50)
# help in table (11,51)
# help in table (11,52)
# help in table (11,53)
# help in table (11,54)
# help in table (11,55)
# help in table (11,56)
# help in table (11,57)
# help in table (11,58)
# help in table (11,59)
# help in table (11,60)
# help in table (11,61)
# help in table (11,62)
# help in table (11,63)
# help in table (11,64)
# help in table (11,65)
# help in table (11,66)
# help in table (11,67)
# help in table (11,68)
# help in table (11,69)
# help in table (11,70)
# help in table (11,71)
# help in table (11,72)
# help in table (11,73)
# help in table (11,74)
# help in table (11,75)
# help in table (11,76)
# help in table (11,77)
# help in table (11,78)
# help in table (11,79)
# help in table (11,80)
# help in table (11,81)
# help in table (11,82)
# help in table (11,83)
# help in table (11,84)
# help in table (11,85)
# help in table (11,86)
# help in table (11,87)
# help in table (11,88)
# help in table (11,89)
# help in table (11,90)
# help in table (11,91)
# help in table (11,92)
# help in table (11,93)
# help in table (11,94)
# help in table (11,95)
# help in table (11,96)
# help in table (11,97)
# help in table (11,98)
# help in table (11,99)
# help in table (11,100)
# help in table (11,101)
# help in table (11,102)
# help in table (11,103)
# help in table (11,104)
# help in table (11,105)
# help in table (11,106)
# help in table (11,107)
# help in table (11,108)
# help in table (11,109)
# help in table (11,110)
# help in table (11,111)
# help in table (11,112)
# help in table (11,113)
# help in table (11,114)
# help in table (11,115)
# help in table (11,116)
# help in table (11,117)
# help in table (11,118)
# help in table (11,119)
# help in table (11,120)
# help in table (11,121)
# help in table (11,122)
# help in table (11,123)
# help in table (11,124)
# help in table (11,125)
# help in table (11,126)
# help in table (11,127)
# help in table (11,128)
# help in table (11,129)
# help in table (11,130)
# help in table (11,131)
# help in table (11,132)
# help in table (11,133)
# help in table (11,134)
# help in table (11,135)
# help in table (11,136)
# help in table (11,137)
# help in table (11,138)
# help in table (11,139)
# help in table (11,140)
# help in table (11,141)
# help in table (11,142)
# help in table (11,143)
# help in table (11,144)
# help in table (11,145)
# help in table (11,146)
# help in table (11,147)
# help in table (11,148)
# help in table (11,149)
# help in table (11,150)
# help in table (11,151)
# help in table (11,152)
# help in table (11,153)
# help in table (11,154)
# help in table (11,155)
# help in table (11,156)
# help in table (11,157)
# help in table (11,158)
# help in table (11,159)
# help in table (11,160)
# help in table (11,161)
# help in table (11,162)
# help in table (11,163)
# help in table (11,164)
# help in table (11,165)
# help in table (11,166)
# help in table (11,167)
# help in table (11,168)
# help in table (11,169)
# help in table (11,170)
# help in table (11,171)
# help in table (11,172)
# help in table (11,173)
# help in table (11,174)
# help in table (11,175)
# help in table (11,176)
# help in table (11,177)
# help in table (11,178)
# help in table (11,179)
# help in table (11,180)
# help in table (11,181)
# help in table (11,182)
# help in table (11,183)
# help in table (11,184)
# help in table (11,185)
# help in table (11,186)
# help in table (11,187)
# help in table (11,188)
# help in table (11,189)
# help in table (11,190)
# help in table (11,191)
# help in table (11,192)
# help in table (11,193)
# help in table (11,194)
# help in table (11,195)
# help in table (11,196)
# help in table (11,197)
# help in table (11,198)
# help in table (11,199)
# help in table (11,200)
# help in table (11,201)
# help in table (11,202)
# help in table (11,203)
# help in table (11,204)
# help in table (11,205)
# help in table (11,206)
# help in table (11,207)
# help in table (11,208)
# help in table (11,209)
# help in table (11,210)
# help in table (11,211)
# help in table (11,212)
# help in table (11,213)
# help in table (11,214)
# help in table (11,215)
# help in table (11,216)
# help in table (11,217)
# help in table (11,218)
# help in table (11,219)
# help in table (11,220)
# help in table (11,221)
# help in table (11,222)
# help in table (11,223)
# help in table (11,224)
# help in table (11,225)
# help in table (11,226)
# help in table (11,227)
# help in table (11,228)
# help in table (11,229)
# help in table (11,230)
# help in table (11,231)
# help in table (11,232)
# help in table (11,233)
# help in table (11,234)
# help in table (11,235)
# help in table (11,236)
# help in table (11,237)
# help in table (11,238)

# %%
for i in range(239):
    newslice_244=slice_244[:,:242,:]
    if not np.array_equal(newslice_244,slice_243):
        print("help in table " + str(i))
# Out:
# help in table 0
# help in table 1
# help in table 2
# help in table 3
# help in table 4
# help in table 5
# help in table 6
# help in table 7
# help in table 8
# help in table 9
# help in table 10
# help in table 11
# help in table 12
# help in table 13
# help in table 14
# help in table 15
# help in table 16
# help in table 17
# help in table 18
# help in table 19
# help in table 20
# help in table 21
# help in table 22
# help in table 23
# help in table 24
# help in table 25
# help in table 26
# help in table 27
# help in table 28
# help in table 29
# help in table 30
# help in table 31
# help in table 32
# help in table 33
# help in table 34
# help in table 35
# help in table 36
# help in table 37
# help in table 38
# help in table 39
# help in table 40
# help in table 41
# help in table 42
# help in table 43
# help in table 44
# help in table 45
# help in table 46
# help in table 47
# help in table 48
# help in table 49
# help in table 50
# help in table 51
# help in table 52
# help in table 53
# help in table 54
# help in table 55
# help in table 56
# help in table 57
# help in table 58
# help in table 59
# help in table 60
# help in table 61
# help in table 62
# help in table 63
# help in table 64
# help in table 65
# help in table 66
# help in table 67
# help in table 68
# help in table 69
# help in table 70
# help in table 71
# help in table 72
# help in table 73
# help in table 74
# help in table 75
# help in table 76
# help in table 77
# help in table 78
# help in table 79
# help in table 80
# help in table 81
# help in table 82
# help in table 83
# help in table 84
# help in table 85
# help in table 86
# help in table 87
# help in table 88
# help in table 89
# help in table 90
# help in table 91
# help in table 92
# help in table 93
# help in table 94
# help in table 95
# help in table 96
# help in table 97
# help in table 98
# help in table 99
# help in table 100
# help in table 101
# help in table 102
# help in table 103
# help in table 104
# help in table 105
# help in table 106
# help in table 107
# help in table 108
# help in table 109
# help in table 110
# help in table 111
# help in table 112
# help in table 113
# help in table 114
# help in table 115
# help in table 116
# help in table 117
# help in table 118
# help in table 119
# help in table 120
# help in table 121
# help in table 122
# help in table 123
# help in table 124
# help in table 125
# help in table 126
# help in table 127
# help in table 128
# help in table 129
# help in table 130
# help in table 131
# help in table 132
# help in table 133
# help in table 134
# help in table 135
# help in table 136
# help in table 137
# help in table 138
# help in table 139
# help in table 140
# help in table 141
# help in table 142
# help in table 143
# help in table 144
# help in table 145
# help in table 146
# help in table 147
# help in table 148
# help in table 149
# help in table 150
# help in table 151
# help in table 152
# help in table 153
# help in table 154
# help in table 155
# help in table 156
# help in table 157
# help in table 158
# help in table 159
# help in table 160
# help in table 161
# help in table 162
# help in table 163
# help in table 164
# help in table 165
# help in table 166
# help in table 167
# help in table 168
# help in table 169
# help in table 170
# help in table 171
# help in table 172
# help in table 173
# help in table 174
# help in table 175
# help in table 176
# help in table 177
# help in table 178
# help in table 179
# help in table 180
# help in table 181
# help in table 182
# help in table 183
# help in table 184
# help in table 185
# help in table 186
# help in table 187
# help in table 188
# help in table 189
# help in table 190
# help in table 191
# help in table 192
# help in table 193
# help in table 194
# help in table 195
# help in table 196
# help in table 197
# help in table 198
# help in table 199
# help in table 200
# help in table 201
# help in table 202
# help in table 203
# help in table 204
# help in table 205
# help in table 206
# help in table 207
# help in table 208
# help in table 209
# help in table 210
# help in table 211
# help in table 212
# help in table 213
# help in table 214
# help in table 215
# help in table 216
# help in table 217
# help in table 218
# help in table 219
# help in table 220
# help in table 221
# help in table 222
# help in table 223
# help in table 224
# help in table 225
# help in table 226
# help in table 227
# help in table 228
# help in table 229
# help in table 230
# help in table 231
# help in table 232
# help in table 233
# help in table 234
# help in table 235
# help in table 236
# help in table 237
# help in table 238
